# %%
#Import all necessary modules
import pandas as pd
import numpy as np
import os

# %%
#create the path and file
json_path =  os.path.join ("purchase_data.json")
file_df = pd.read_json(json_path)
file_df.count()
# Out:
# Age          780
# Gender       780
# Item ID      780
# Item Name    780
# Price        780
# SN           780
# dtype: int64

# %%
#Get generall feel of the data
file_df.columns
# Out:
# Index(['Age', 'Gender', 'Item ID', 'Item Name', 'Price', 'SN'], dtype='object')

# %%
#See what kind of types are in the data
file_df.dtypes
# Out:
# Age            int64
# Gender        object
# Item ID        int64
# Item Name     object
# Price        float64
# SN            object
# dtype: object

# %% [markdown]
# ** Player Count**

# %%
#Total Number of Players
total_players = file_df["Item Name"].count()

total_players_df = pd.DataFrame({'Total Players': total_players}, index = [" "])
total_players_df
# Out:
#    Total Players
#              780

# %% [markdown]
# **Purchasing Analysis (Total)**

# %%
# Number of Unique Items
unique_items = file_df["Item Name"].nunique()
unique_items
# Out:
# 179

# %%
#average purchases price
average_purchase = np.round((file_df["Price"].mean()),decimals=2)
average_purchase_clean = '${:,.2f}'.format(average_purchase)
average_purchase_clean
# Out:
# '$2.93'

# %%
# Total Number of Purchases
total_purchases = file_df["Price"].value_counts().sum()
total_purchases
# Out:
# 780

# %%
# Total Revenue
total_revenue = pd.to_numeric(average_purchase) * (total_purchases)
total_revenue = '${:,.2f}'.format(total_revenue)
total_revenue
# Out:
# '$2,285.40'

# %%
purchasing_analysis_df = pd.DataFrame({'Number of Unique Items':unique_items,
                                      'Average Price':average_purchase_clean,
                                      'Number of Purchases': total_purchases,
                                      'Total Revenue': total_revenue}, index = [" "])
purchasing_analysis_df
# Out:
#   Average Price  Number of Purchases  Number of Unique Items Total Revenue
#           $2.93                  780                     179     $2,285.40

# %% [markdown]
# **Gender Demographics**

# %%
file_df.groupby("Gender").count()
# Out:
#                        Age  Item ID  Item Name  Price   SN
# Gender
# Female                 136      136        136    136  136
# Male                   633      633        633    633  633
# Other / Non-Disclosed   11       11         11     11   11

# %%
# Percentage and Count of Male Players
filtered_male = len(file_df.loc[file_df["Gender"]=="Male"])
filtered_male_percent = (filtered_male/total_players).round(3)
filtered_male_percent = "{0:.2f}%".format(filtered_male_percent * 100) 
filtered_male_percent
# Out:
# '81.20%'

# %%
# Percentage and Count of Female Players
filtered_female = len(file_df.loc[file_df["Gender"]=="Female"])
filtered_female_percent = (filtered_female/total_players).round(3)
filtered_female_percent = "{0:.2f}%".format(filtered_female_percent * 100) 
filtered_female_percent
# Out:
# '17.40%'

# %%
file_df['Gender'].value_counts()
# Out:
# Male                     633
# Female                   136
# Other / Non-Disclosed     11
# Name: Gender, dtype: int64

# %%
#Percentage and Count of Other / Non-Disclosed

filtered_other = len(file_df.loc[file_df["Gender"]=="Other / Non-Disclosed"])
filtered_other_percent = (filtered_other/total_players).round(3)
filtered_other_percent = "{0:.2f}%".format(filtered_other_percent * 100) 
filtered_other_percent
# Out:
# '1.40%'

# %%
gender_demo_df = pd.DataFrame({'Total Count': [filtered_male, filtered_female,
                                                   filtered_other],
                               'Percentage of Players':[filtered_male_percent,
                                                        filtered_female_percent,
                                                        filtered_other_percent]}, 
                                index = ['Male', 'Female', 'Other / Non-Disclosed'])
gender_demo_df
# Out:
#                       Percentage of Players  Total Count
# Male                                 81.20%          633
# Female                               17.40%          136
# Other / Non-Disclosed                 1.40%           11

# %% [markdown]
# **Purchasing Analysis (Gender)**

# %%
# The below each broken by gender
grouped_count = pd.DataFrame(file_df.groupby(['Gender'])['Price'].count())

# %%
#Average Purchase Price
grouped_purch = pd.DataFrame(file_df.groupby(['Gender'])['Price'].mean())

# %%
#Total Purchase Value
group_purch_value = pd.DataFrame(file_df.groupby(['Gender'])['Price'].sum())

# %%
normalized = group_purch_value.div(grouped_count.iloc[0], axis='columns')

# %%
normalized.columns = ['Normalized Totals']
grouped_purch.columns = ['Average Purchase Price']
group_purch_value.columns = ['Total Purchase Value']
grouped_count.columns = ['Purchase Count']


purchasing_ana_gen =pd.concat([grouped_count,group_purch_value,normalized], axis=1)
purchasing_ana_gen
# Out:
#                        Purchase Count  Total Purchase Value  Normalized Totals
# Gender
# Female                            136                382.91           2.815515
# Male                              633               1867.68          13.732941
# Other / Non-Disclosed              11                 35.74           0.262794

# %% [markdown]
# **Age Demographics**

# %%
# The below each broken into bins of 4 years (i.e. &lt;10, 10-14, 15-19, etc.) 
# Purchase Count
# Average Purchase Price
# Total Purchase Value
# Normalized Totals

# %% [markdown]
# **Top Spenders**

# %%
purchase_amt_by_SN = pd.DataFrame(file_df.groupby('SN').sum()["Price"])
num_purchase_by_SN = pd.DataFrame(file_df.groupby('SN').count()["Price"])
avg_purchase_by_SN = pd.DataFrame(file_df.groupby('SN').mean()["Price"])

purchase_amt_by_SN = purchase_amt_by_SN.rename(columns={'Price': 'Total Purchase Value'})
num_purchase_by_SN = num_purchase_by_SN.rename(columns={'Price': 'Number of Purchases'})
avg_purchase_by_SN = avg_purchase_by_SN.rename(columns={'Price': 'Average Purchase'})

# %%
top_spender_sn_df =pd.concat([purchase_amt_by_SN,num_purchase_by_SN,num_purchase_by_SN], axis=1)
top_spender_sn_df.sort_values("Total Purchase Value", ascending=False).head(5)
# Out:
#              Total Purchase Value  Number of Purchases  Number of Purchases
# SN
# Undirrala66                 17.06                    5                    5
# Saedue76                    13.56                    4                    4
# Mindimnya67                 12.74                    4                    4
# Haellysu29                  12.73                    3                    3
# Eoda93                      11.58                    3                    3

# %% [markdown]
# **Most Popular Items**

# %%
# Identify the 5 most popular items by purchase count, then list (in a table):
# Item ID
# Item Name
# Purchase Count
# Item Price
# Total Purchase Value

# %%
# pop_it= file_df[["Price","Item ID","Item Name"]]

# pop_sum = pd.DataFrame(file_df.groupby("Item Name").sum()["Price"])
# pop_sum = pop_sum.rename(columns={'Price': 'Total Purchase Value'})

# pop_count = pd.DataFrame(file_df.groupby("Item Name").count()["Price"])
# pop_count = pop_count.rename(columns={'Price': 'Purchase Count'})

# %%
pop_it= file_df[["Price","Item ID","Item Name"]]

pop_sum = pd.DataFrame(pop_it.groupby("Item Name").sum()["Price"])


pop_count = pd.DataFrame(pop_it.groupby("Item Name").count()["Price"])

# %%
op_df = pd.concat([pop_it, pop_sum, pop_count], axis=1)
op_df
# Out:
# /Users/jessicaburgos/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/indexes/api.py:57: RuntimeWarning: '<' not supported between instances of 'str' and 'int', sort order is undefined for incomparable objects
#   union = _union_indexes(indexes)
#                                           Price  Item ID  \
# 0                                          3.37    165.0
# 1                                          2.32    119.0
# 2                                          2.46    174.0
# 3                                          1.36     92.0
# 4                                          1.27     63.0
# 5                                          1.73     10.0
# 6                                          4.57    153.0
# 7                                          3.32    169.0
# 8                                          2.77    118.0
# 9                                          4.53     99.0
# 10                                         3.81     57.0
# 11                                         1.55     47.0
# 12                                         4.06     81.0
# 13                                         3.68     77.0
# 14                                         2.46     44.0
# 15                                         4.77     96.0
# 16                                         1.14    123.0
# 17                                         1.65     59.0
# 18                                         3.71     91.0
# 19                                         4.89    177.0
# 20                                         2.33     78.0
# 21                                         1.79      3.0
# 22                                         2.52     11.0
# 23                                         2.36    183.0
# 24                                         1.96     65.0
# 25                                         1.27     63.0
# 26                                         3.90    132.0
# 27                                         2.29    106.0
# 28                                         4.23     49.0
# 29                                         2.46     45.0
# ...                                         ...      ...
# Thorn, Conqueror of the Corrupted           NaN      NaN
# Thorn, Satchel of Dark Souls                NaN      NaN
# Thunderfury Scimitar                        NaN      NaN
# Toothpick                                   NaN      NaN
# Torchlight, Bond of Storms                  NaN      NaN
# Tranquility, Razor of Black Magic           NaN      NaN
# Trickster                                   NaN      NaN
# Twilight's Carver                           NaN      NaN
# Undead Crusader                             NaN      NaN
# Unending Tyranny                            NaN      NaN
# Unholy Wand                                 NaN      NaN
# Vengeance Cleaver                           NaN      NaN
# Venom Claymore                              NaN      NaN
# Verdict                                     NaN      NaN
# Victor Iron Spikes                          NaN      NaN
# Vindictive Glass Edge                       NaN      NaN
# War-Forged Gold Deflector                   NaN      NaN
# Warmonger, Gift of Suffering's End          NaN      NaN
# Warped Diamond Crusader                     NaN      NaN
# Warped Fetish                               NaN      NaN
# Warped Iron Scimitar                        NaN      NaN
# Whistling Mithril Warblade                  NaN      NaN
# Winter's Bite                               NaN      NaN
# Winterthorn, Defender of Shifting Worlds    NaN      NaN
# Woeful Adamantite Claymore                  NaN      NaN
# Wolf                                        NaN      NaN
# Wolf, Promise of the Moonwalker             NaN      NaN
# Worldbreaker                                NaN      NaN
# Yearning Crusher                            NaN      NaN
# Yearning Mageblade                          NaN      NaN
#
#                                                                           Item Name  \
# 0                                                       Bone Crushing Silver Skewer
# 1                                         Stormbringer, Dark Blade of Ending Misery
# 2                                                                   Primitive Blade
# 3                                                                      Final Critic
# 4                                                                    Stormfury Mace
# 5                                                                       Sleepwalker
# 6                                                                   Mercenary Sabre
# 7                                            Interrogator, Blood Blade of the Queen
# 8                                                  Ghost Reaver, Longsword of Magic
# 9                                              Expiration, Warscythe Of Lost Worlds
# 10                                                  Despair, Favor of Due Diligence
# 11                                                      Alpha, Reach of Ending Hope
# 12                                                                        Dreamkiss
# 13                                                       Piety, Guardian of Riddles
# 14                                                            Bonecarvin Battle Axe
# 15                                                      Blood-Forged Skeletal Spine
# 16                                                                Twilight's Carver
# 17                                                    Lightning, Etcher of the King
# 18                                                                          Celeste
# 19                                         Winterthorn, Defender of Shifting Worlds
# 20                                                       Glimmer, Ender of the Moon
# 21                                                                     Phantomlight
# 22                                                                        Brimstone
# 23                                                              Dragon's Greatsword
# 24                                                        Conqueror Adamantite Mace
# 25                                                                   Stormfury Mace
# 26                                                                       Persuasion
# 27                                                              Crying Steel Sickle
# 28                                                 The Oculus, Token of Lost Worlds
# 29                                                              Glinting Glass Edge
# ...                                                                             ...
# Thorn, Conqueror of the Corrupted                                               NaN
# Thorn, Satchel of Dark Souls                                                    NaN
# Thunderfury Scimitar                                                            NaN
# Toothpick                                                                       NaN
# Torchlight, Bond of Storms                                                      NaN
# Tranquility, Razor of Black Magic                                               NaN
# Trickster                                                                       NaN
# Twilight's Carver                                                               NaN
# Undead Crusader                                                                 NaN
# Unending Tyranny                                                                NaN
# Unholy Wand                                                                     NaN
# Vengeance Cleaver                                                               NaN
# Venom Claymore                                                                  NaN
# Verdict                                                                         NaN
# Victor Iron Spikes                                                              NaN
# Vindictive Glass Edge                                                           NaN
# War-Forged Gold Deflector                                                       NaN
# Warmonger, Gift of Suffering's End                                              NaN
# Warped Diamond Crusader                                                         NaN
# Warped Fetish                                                                   NaN
# Warped Iron Scimitar                                                            NaN
# Whistling Mithril Warblade                                                      NaN
# Winter's Bite                                                                   NaN
# Winterthorn, Defender of Shifting Worlds                                        NaN
# Woeful Adamantite Claymore                                                      NaN
# Wolf                                                                            NaN
# Wolf, Promise of the Moonwalker                                                 NaN
# Worldbreaker                                                                    NaN
# Yearning Crusher                                                                NaN
# Yearning Mageblade                                                              NaN
#
#                                           Price  Price
# 0                                           NaN    NaN
# 1                                           NaN    NaN
# 2                                           NaN    NaN
# 3                                           NaN    NaN
# 4                                           NaN    NaN
# 5                                           NaN    NaN
# 6                                           NaN    NaN
# 7                                           NaN    NaN
# 8                                           NaN    NaN
# 9                                           NaN    NaN
# 10                                          NaN    NaN
# 11                                          NaN    NaN
# 12                                          NaN    NaN
# 13                                          NaN    NaN
# 14                                          NaN    NaN
# 15                                          NaN    NaN
# 16                                          NaN    NaN
# 17                                          NaN    NaN
# 18                                          NaN    NaN
# 19                                          NaN    NaN
# 20                                          NaN    NaN
# 21                                          NaN    NaN
# 22                                          NaN    NaN
# 23                                          NaN    NaN
# 24                                          NaN    NaN
# 25                                          NaN    NaN
# 26                                          NaN    NaN
# 27                                          NaN    NaN
# 28                                          NaN    NaN
# 29                                          NaN    NaN
# ...                                         ...    ...
# Thorn, Conqueror of the Corrupted          4.08    2.0
# Thorn, Satchel of Dark Souls              27.06    6.0
# Thunderfury Scimitar                       9.06    3.0
# Toothpick                                 17.40    5.0
# Torchlight, Bond of Storms                12.39    7.0
# Tranquility, Razor of Black Magic          4.94    2.0
# Trickster                                 18.63    9.0
# Twilight's Carver                          5.70    5.0
# Undead Crusader                           18.68    4.0
# Unending Tyranny                           3.63    3.0
# Unholy Wand                                7.52    4.0
# Vengeance Cleaver                         11.10    3.0
# Venom Claymore                            16.32    6.0
# Verdict                                    3.40    1.0
# Victor Iron Spikes                        24.85    7.0
# Vindictive Glass Edge                      8.52    2.0
# War-Forged Gold Deflector                 11.19    3.0
# Warmonger, Gift of Suffering's End        23.76    6.0
# Warped Diamond Crusader                   13.98    3.0
# Warped Fetish                              4.82    2.0
# Warped Iron Scimitar                       8.16    2.0
# Whistling Mithril Warblade                17.28    4.0
# Winter's Bite                              2.78    2.0
# Winterthorn, Defender of Shifting Worlds  19.56    4.0
# Woeful Adamantite Claymore                11.16    9.0
# Wolf                                       9.20    5.0
# Wolf, Promise of the Moonwalker           13.16    7.0
# Worldbreaker                               6.58    2.0
# Yearning Crusher                           2.12    2.0
# Yearning Mageblade                         7.16    4.0
#
# [959 rows x 5 columns]

# %%
# %whos
# Out:
# Variable                  Type         Data/Info
# ------------------------------------------------
# ave_p_val                 DataFrame                   Average Pu<...>                     4.89
# average_purchase          float64      2.93
# average_purchase_clean    str          $2.93
# avg_purchase_by_SN        DataFrame                     Average <...>n\n[573 rows x 1 columns]
# file_df                   DataFrame         Age                 <...>n\n[780 rows x 6 columns]
# filtered_female           int          136
# filtered_female_percent   str          17.40%
# filtered_male             int          633
# filtered_male_percent     str          81.20%
# filtered_other            int          11
# filtered_other_percent    str          1.40%
# gender_demo_df            DataFrame                          Per<...>       1.40%           11
# group_purch_value         DataFrame                           To<...>sed                 35.74
# groupe_purch_value        DataFrame                             <...> / Non-Disclosed    35.74
# grouped_count             DataFrame                           Pu<...>Disclosed              11
# grouped_purch             DataFrame                           Av<...>d                3.249091
# json_path                 str          purchase_data.json
# merged_top5               DataFrame                   Price\nSN <...>n\n[573 rows x 1 columns]
# most_pop                  DataFrame         Item ID             <...>           13.41    9.0
# n                         DataFrame                           Av<...>               NaN    NaN
# normalized                DataFrame                           No<...>closed           0.262794
# np                        module       <module 'numpy' from '/Us<...>kages/numpy/__init__.py'>
# num_purchase_by_SN        DataFrame                     Number o<...>n\n[573 rows x 1 columns]
# on                        DataFrame         Age  Gender  Item ID<...> Mace   3.74     Saedue76
# op_df                     DataFrame                             <...>n\n[959 rows x 5 columns]
# os                        module       <module 'os' from '/Users<...>ata/lib/python3.6/os.py'>
# p                         DataFrame                             <...>n\n[183 rows x 2 columns]
# p_count                   DataFrame                     Age  Gen<...>n\n[573 rows x 5 columns]
# pc_count_female           int          136
# pc_count_male             int          633
# pc_count_other            int          11
# pd                        module       <module 'pandas' from '/U<...>ages/pandas/__init__.py'>
# pop                       DataFrame                             <...>n\n[179 rows x 1 columns]
# pop_count                 DataFrame                             <...>n\n[179 rows x 1 columns]
# pop_df                    DataFrame         Item ID             <...>n\n[780 rows x 5 columns]
# pop_it                    DataFrame         Price  Item ID      <...>n\n[780 rows x 3 columns]
# pop_ite                   DataFrame                             <...>n\n[183 rows x 2 columns]
# pop_item_count            DataFrame             Count\nItem ID  <...>n\n[183 rows x 1 columns]
# pop_item_pv               DataFrame             Total Purchase A<...>n\n[183 rows x 1 columns]
# pop_item_sum              DataFrame             Price\nItem ID  <...>n\n[183 rows x 1 columns]
# pop_sum                   DataFrame                             <...>n\n[179 rows x 1 columns]
# purchase_amt_by_SN        DataFrame                     Total Pu<...>n\n[573 rows x 1 columns]
# purchasing_ana_gen        DataFrame                           Pu<...> 35.74           0.262794
# purchasing_analysis_df    DataFrame      Average Price  Number o<...>        179     $2,285.40
# t                         DataFrame         Age Gender  Item ID <...> Mace   3.74     Saedue76
# top_spender               DataFrame                   Purchase C<...>NaN                 17.06
# top_spender_sn_df         DataFrame                     Total Pu<...>n\n[573 rows x 3 columns]
# total_p_val               DataFrame                 Price\nSN   <...>12.73\nEoda93       11.58
# total_players             int64        780
# total_players_df          DataFrame       Total Players\n             780
# total_purchases           int64        780
# total_revenue             str          $2,285.40
# unique_items              int          179
# y                         DataFrame                             <...>n\n[959 rows x 5 columns]

# %%
op_df = pd.concat([pop_it, pop_item_pv, pop_item_count], axis=1)
op_df
# Out:
#      Price  Item ID                                  Item Name  \
# 0     3.37      165                Bone Crushing Silver Skewer
# 1     2.32      119  Stormbringer, Dark Blade of Ending Misery
# 2     2.46      174                            Primitive Blade
# 3     1.36       92                               Final Critic
# 4     1.27       63                             Stormfury Mace
# 5     1.73       10                                Sleepwalker
# 6     4.57      153                            Mercenary Sabre
# 7     3.32      169     Interrogator, Blood Blade of the Queen
# 8     2.77      118           Ghost Reaver, Longsword of Magic
# 9     4.53       99       Expiration, Warscythe Of Lost Worlds
# 10    3.81       57            Despair, Favor of Due Diligence
# 11    1.55       47                Alpha, Reach of Ending Hope
# 12    4.06       81                                  Dreamkiss
# 13    3.68       77                 Piety, Guardian of Riddles
# 14    2.46       44                      Bonecarvin Battle Axe
# 15    4.77       96                Blood-Forged Skeletal Spine
# 16    1.14      123                          Twilight's Carver
# 17    1.65       59              Lightning, Etcher of the King
# 18    3.71       91                                    Celeste
# 19    4.89      177   Winterthorn, Defender of Shifting Worlds
# 20    2.33       78                 Glimmer, Ender of the Moon
# 21    1.79        3                               Phantomlight
# 22    2.52       11                                  Brimstone
# 23    2.36      183                        Dragon's Greatsword
# 24    1.96       65                  Conqueror Adamantite Mace
# 25    1.27       63                             Stormfury Mace
# 26    3.90      132                                 Persuasion
# 27    2.29      106                        Crying Steel Sickle
# 28    4.23       49           The Oculus, Token of Lost Worlds
# 29    2.46       45                        Glinting Glass Edge
# ..     ...      ...                                        ...
# 750   1.28       86                          Stormfury Lantern
# 751   1.88      179            Wolf, Promise of the Moonwalker
# 752   2.37      116                    Renewed Skeletal Katana
# 753   2.28        4                         Bloodlord's Fetish
# 754   1.36      104                         Gladiator's Glaive
# 755   1.88      179            Wolf, Promise of the Moonwalker
# 756   1.20        6                                Rusty Skull
# 757   2.52       11                                  Brimstone
# 758   1.21      122                           Unending Tyranny
# 759   2.20       87                   Deluge, Edge of the West
# 760   4.06       81                                  Dreamkiss
# 761   1.24      175                 Woeful Adamantite Claymore
# 762   4.39       52                                     Hatred
# 763   4.32       48            Rage, Legacy of the Lone Victor
# 764   3.89       70                                 Hope's End
# 765   1.49       13                                   Serenity
# 766   2.23       84                                 Arcane Gem
# 767   1.21      122                           Unending Tyranny
# 768   3.56      158         Darkheart, Butcher of the Champion
# 769   3.74       73                                Ritual Mace
# 770   3.27      141                                 Persuasion
# 771   1.03       25                                  Hero Cane
# 772   2.07       31                                  Trickster
# 773   2.46       44                      Bonecarvin Battle Axe
# 774   1.14      123                          Twilight's Carver
# 775   3.62       98                Deadline, Voice Of Subtlety
# 776   1.36      104                         Gladiator's Glaive
# 777   4.15      117          Heartstriker, Legacy of the Light
# 778   1.72       75                    Brutality Ivory Warmace
# 779   3.61      107                  Splitter, Foe Of Subtlety
#
#      Total Purchase Amount  Count
# 0                     1.82    1.0
# 1                     9.12    4.0
# 2                     3.40    1.0
# 3                     1.79    1.0
# 4                     2.28    1.0
# 5                     3.96    3.0
# 6                     3.60    3.0
# 7                    27.06    6.0
# 8                    23.46    6.0
# 9                     4.08    2.0
# 10                   10.38    6.0
# 11                   17.64    7.0
# 12                   21.50    5.0
# 13                   13.41    9.0
# 14                    7.95    5.0
# 15                    6.18    6.0
# 16                   12.44    4.0
# 17                   10.41    3.0
# 18                   12.39    7.0
# 19                    7.96    2.0
# 20                    5.92    4.0
# 21                    9.81    3.0
# 22                   21.42    6.0
# 23                   11.08    4.0
# 24                    4.82    2.0
# 25                    4.12    4.0
# 26                    7.52    4.0
# 27                   15.84    4.0
# 28                    3.04    1.0
# 29                   11.37    3.0
# ..                     ...    ...
# 750                    NaN    NaN
# 751                    NaN    NaN
# 752                    NaN    NaN
# 753                    NaN    NaN
# 754                    NaN    NaN
# 755                    NaN    NaN
# 756                    NaN    NaN
# 757                    NaN    NaN
# 758                    NaN    NaN
# 759                    NaN    NaN
# 760                    NaN    NaN
# 761                    NaN    NaN
# 762                    NaN    NaN
# 763                    NaN    NaN
# 764                    NaN    NaN
# 765                    NaN    NaN
# 766                    NaN    NaN
# 767                    NaN    NaN
# 768                    NaN    NaN
# 769                    NaN    NaN
# 770                    NaN    NaN
# 771                    NaN    NaN
# 772                    NaN    NaN
# 773                    NaN    NaN
# 774                    NaN    NaN
# 775                    NaN    NaN
# 776                    NaN    NaN
# 777                    NaN    NaN
# 778                    NaN    NaN
# 779                    NaN    NaN
#
# [780 rows x 5 columns]

# %%
most_pop = pop_df.sort_values("Count", ascending=False).head(5)
most_pop
# Out:
#      Item ID                            Item Name  Price  \
# 39        63                       Stormfury Mace   1.27
# 84         7         Thorn, Satchel of Dark Souls   4.51
# 31        37  Shadow Strike, Glory of Ending Hope   1.93
# 175       34                      Retribution Axe   4.14
# 13        77           Piety, Guardian of Riddles   3.68
#
#      Total Purchase Amount  Count
# 39                   25.85   11.0
# 84                   24.53   11.0
# 31                   18.63    9.0
# 175                  11.16    9.0
# 13                   13.41    9.0

# %% [markdown]
# **Most Profitable Items**

# %%
# Identify the 5 most profitable items by total purchase value, then list (in a table):
# Item ID
# Item Name
# Purchase Count
# Item Price
# Total Purchase Value

# %%
pop_it= file_df["Price","Item ID", "Item Name]
# Out:
#   File "<ipython-input-427-ceaad2ff5bd5>", line 1
#     pop_it= file_df["Price","Item ID", "Item Name]
#                                                   ^
# SyntaxError: EOL while scanning string literal

# %%
op_df = pd.concat([pop_it, pop_item_pv, pop_item_count], axis=1)

pop_df.sort_values("Total Purchase Amount", ascending=False).head(5)

# %%
# As final considerations:
# * You must submit a link to your Jupyter Notebook with the viewable Data Frames. 
# * You must include an exported markdown version of your Notebook called  `README.md` in your GitHub repository.  
# * You must include a written description of three observable trends based on the data.
